# %%
import pandas as pd

df = pd.read_pickle("eval_results.pkl")
df[df["env"] == "Freeway"].sort_values(by=["reward_mean"])
#df = df.drop(df[(df.score < 50) & (df.score > 20)].index)
#df[df["env"] == "Pong"]
# Out:
#          env   variant train_seed  eval_seed  episodes  reward_mean  \
# 119  Freeway  iscobots         16       1011         5     0.000000
# 117  Freeway  iscobots         16        456         5     0.000000
# 116  Freeway  iscobots         16        123         5     0.000000
# 118  Freeway  iscobots         16        789         5     0.000000
# 115  Freeway  iscobots          0       1011         5    27.000000
# 112  Freeway  iscobots          0        123         5    27.000000
# 113  Freeway  iscobots          0        456         5    28.400000
# 114  Freeway  iscobots          0        789         5    28.799999
# 110  Freeway  iscobots         32        789         5    30.200001
# 111  Freeway  iscobots         32       1011         5    30.600000
# 109  Freeway  iscobots         32        456         5    30.600000
# 108  Freeway  iscobots         32        123         5    30.600000
# 103  Freeway   scobots         32       1011         5    31.400000
# 96   Freeway   scobots          0        123         5    31.600000
# 101  Freeway   scobots         32        456         5    31.600000
# 98   Freeway   scobots          0        789         5    31.600000
# 102  Freeway   scobots         32        789         5    31.799999
# 97   Freeway   scobots          0        456         5    31.799999
# 105  Freeway   scobots         16        456         5    32.000000
# 104  Freeway   scobots         16        123         5    32.000000
# 100  Freeway   scobots         32        123         5    32.000000
# 99   Freeway   scobots          0       1011         5    32.000000
# 106  Freeway   scobots         16        789         5    32.000000
# 107  Freeway   scobots         16       1011         5    32.000000
#
#      reward_std  steps_mean  steps_std
# 119    0.000000      2048.0        0.0
# 117    0.000000      2048.0        0.0
# 116    0.000000      2048.0        0.0
# 118    0.000000      2048.0        0.0
# 115    1.673320      2048.0        0.0
# 112    2.097618      2048.0        0.0
# 113    1.019804      2048.0        0.0
# 114    1.720465      2048.0        0.0
# 110    0.748331      2048.0        0.0
# 111    0.489898      2048.0        0.0
# 109    0.800000      2048.0        0.0
# 108    0.800000      2048.0        0.0
# 103    0.489898      2048.0        0.0
# 96     0.489898      2048.0        0.0
# 101    0.489898      2048.0        0.0
# 98     0.489898      2048.0        0.0
# 102    0.400000      2048.0        0.0
# 97     0.400000      2048.0        0.0
# 105    0.000000      2048.0        0.0
# 104    0.000000      2048.0        0.0
# 100    0.000000      2048.0        0.0
# 99     0.000000      2048.0        0.0
# 106    0.000000      2048.0        0.0
# 107    0.000000      2048.0        0.0

# %%
grouped = df.groupby(["env", "variant"])

grouped["reward_mean"].agg(["mean", "std"])
# Out:
#                           mean         std
# env      variant
# Asterix  iscobots  1746.666626  216.724934
#          rgb         24.854546    4.160310
#          scobots    597.500000  304.604811
# Bowling  rgb         10.000000    0.000000
# Freeway  rgb         32.555557    0.409607
# Kangaroo iscobots  1790.000000   54.272042
#          rgb          2.093333    0.700213
#          scobots    218.333328  113.284303
# Pong     rgb         -0.383333    3.070633
